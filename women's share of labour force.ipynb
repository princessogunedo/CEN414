# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
labourforce = pd.read_csv('female.csv')

# %%
labourforce.head()
# Out:
#                        Country Code  Year  \
# 0  Africa Eastern and Southern  NaN  2010
# 1  Africa Eastern and Southern  NaN  2011
# 2  Africa Eastern and Southern  NaN  2012
# 3  Africa Eastern and Southern  NaN  2013
# 4  Africa Eastern and Southern  NaN  2014
#
#    female labour participation rate (%)
# 0                             65.531435
# 1                             65.440779
# 2                             65.308216
# 3                             65.412076
# 4                             65.376603

# %%
sns.barplot(labourforce['Year'], labourforce['female labour participation rate (%)'])
# Out:
# C:\Users\PRINCESS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year', ylabel='female labour participation rate (%)'>

# %%
sns.distplot(labourforce['female labour participation rate (%)'])
# Out:
# C:\Users\PRINCESS\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='female labour participation rate (%)', ylabel='Density'>

# %%
sns.pairplot(labourforce[['Country', 'Year', 'female labour participation rate (%)']])
